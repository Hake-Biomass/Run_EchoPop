# %%
import json
#param_dict=json.load("RT_params.json")
# Opening and reading the JSON file
with open('RT_params.json', 'r') as f:
    # Parsing the JSON file into a Python dictionary
    param_dict = json.load(f)
print(param_dict["PATHCONFIG"]["DATA_ROOT"])
# Out:
# C:/rthomas/Projects/EchoPop_validation/Data
